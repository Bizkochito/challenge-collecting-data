# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

test_url = "https://www.immoweb.be/en/classified/villa/for-sale/andenne/5300/10561076"


response = requests.get(test_url)
test_page = response.text
soup = BeautifulSoup(test_page, "html.parser")
table = soup.find_all('table', class_='classified-table')

df_list = pd.read_html(test_page)
dictionary = {}


for df in df_list:
    dictionary.update(df.to_dict())

print(dictionary)

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

test_url = "https://www.immoweb.be/en/classified/villa/for-sale/andenne/5300/10561076"
#cookie_url = "https://www.immoweb.be/cookie"

#cookie = requests.get(cookie_url)
response = requests.get(test_url)
test_page = response.text

dfs = pd.read_html(test_page)
full_df = pd.concat(dfs)
  # pd.read_html reads in all tables and returns a list of DataFrames

# %%
full_df
# Out:
#                                               0
# 0                               Available as of  \
# 1                     Neighbourhood or locality
# 2                             Construction year
# 3                            Building condition
# 4                         Street frontage width
# 5                           Number of frontages
# 6                        Outdoor parking spaces
# 7                             Surroundings type
# 0                                   Living area
# 1                           Living room surface
# 2                                  Kitchen type
# 3                                      Bedrooms
# 4                             Bedroom 1 surface
# 5                             Bedroom 2 surface
# 6                             Bedroom 3 surface
# 7                                     Bathrooms
# 8                                       Toilets
# 9                    Professional space surface
# 10                             Basement surface
# 11                                    Furnished
# 0                           Surface of the plot
# 1                   Connection to sewer network
# 2                                Garden surface
# 3                               Terrace surface
# 0                    Primary energy consumption
# 1                                  Energy class
# 2                                           NaN
# 3            Reference number of the EPC report
# 4                                  CO₂ emission
# 5   Yearly theoretical total energy consumption
# 6                                  Heating type
# 0                  Planning permission obtained
# 1                  Total ground floor buildable
# 2                            Subdivision permit
# 3                   Latest land use designation
# 0                                         Price
# 1                              Cadastral income
# 2                             Tenement building
# 3                                           NaN
# 0                                       Address
# 1                                       Website
# 2                            External reference
#
#                                                1
# 0                         After signing the deed
# 1                                    Huy et 5kms
# 2                                           2009
# 3                                         As new
# 4                                           11 m
# 5                                              4
# 6                                              2
# 7                                    Countryside
# 0                          195  m² square meters
# 1                           54  m² square meters
# 2                                      Installed
# 3                                              3
# 4                           15  m² square meters
# 5                           15  m² square meters
# 6                           11  m² square meters
# 7                                              1
# 8                                              2
# 9                           38  m² square meters
# 10                          10  m² square meters
# 11                                            No
# 0                         870  m²  square meters
# 1                                  Not connected
# 2                         515  m²  square meters
# 3                          30  m²  square meters
# 0   170  kWh/m²  kilowatt hour per square meters
# 1                                              B
# 2                                            NaN
# 3                                 20230303020972
# 4                                   43 kg CO₂/m²
# 5                                 28008 kWh/year
# 6                                       Fuel oil
# 0                                            Yes
# 1                          88  m²  square meters
# 2                                            Yes
# 3      Living area (residential, urban or rural)
# 0                            € 440,000  440000 €
# 1                                   € 847  847 €
# 2                                             No
# 3                                            NaN
# 0     Chaussée de Tirlemont 15/1 4260  - Braives
# 1                   http://www.immodemarneffe.be
# 2                                        5337311
